# %%
from bet_fetcher import *
from bet_analizator import *
from gamelogs_fetcher import *
bets = all_today_bets()
# Out:
# 1008151201
# 1008151209
# 1008151199
# 1008151221
# 1008151190
# 1008151324
# 1007972409
# 1007972410
# 1007972411
# 1007972412
# 1007972413
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16000/716489757.py in <module>
#       2 from bet_analizator import *
#       3 from gamelogs_fetcher import *
# ----> 4 bets = all_today_bets()
#
# ~\PycharmProjects\nbawoj\bet_fetcher.py in all_today_bets()
#      93         print(game_id)
#      94         result.extend(game_betoffer_list(event_id=game_id))
# ---> 95     result['home_ESPN'] = NORMALIZED_TEAM_NAME[result['home']]
#      96     result['away_ESPN'] = NORMALIZED_TEAM_NAME[result['away']]
#      97     return result
#
# TypeError: list indices must be integers or slices, not str

# %%
bets
# Out:
# [{'name': 'Gobert, Rudy',
#   'name_ESPN': 'RudyGobert',
#   'odds': 1.89,
#   'line': 29.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Conley, Mike',
#   'name_ESPN': 'MikeConley',
#   'odds': 1.94,
#   'line': 23.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': "O'Neale, Royce",
#   'name_ESPN': "RoyceO'Neale",
#   'odds': 2.0,
#   'line': 15.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Theis, Daniel',
#   'name_ESPN': 'DanielTheis',
#   'odds': 1.89,
#   'line': 14.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Wood, Christian',
#   'name_ESPN': 'ChristianWood',
#   'odds': 1.89,
#   'line': 31.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Green, Jalen',
#   'name_ESPN': 'JalenGreen',
#   'odds': 1.89,
#   'line': 19.5,
# ...

# %%
bets = [{'name': 'Gobert, Rudy', 'name_ESPN': 'RudyGobert', 'odds': 1.89, 'line': 29.5, 'bet_on_stat': 'ARP', 'home': 'hou', 'away': 'utah'}, {'name': 'Conley, Mike', 'name_ESPN': 'MikeConley', 'odds': 1.94, 'line': 23.5, 'bet_on_stat': 'ARP', 'home': 'hou', 'away': 'utah'}, {'name': "O'Neale, Royce", 'name_ESPN': "RoyceO'Neale", 'odds': 2.0, 'line': 15.5, 'bet_on_stat': 'ARP', 'home': 'hou', 'away': 'utah'}, {'name': 'Theis, Daniel', 'name_ESPN': 'DanielTheis', 'odds': 1.89, 'line': 14.5, 'bet_on_stat': 'ARP', 'home': 'hou', 'away': 'utah'}, {'name': 'Wood, Christian', 'name_ESPN': 'ChristianWood', 'odds': 1.89, 'line': 31.5, 'bet_on_stat': 'ARP', 'home': 'hou', 'away': 'utah'}, {'name': 'Green, Jalen', 'name_ESPN': 'JalenGreen', 'odds': 1.89, 'line': 19.5, 'bet_on_stat': 'ARP', 'home': 'hou', 'away': 'utah'}, {'name': 'Tate, JaeSean', 'name_ESPN': 'JaeSeanTate', 'odds': 1.89, 'line': 19.5, 'bet_on_stat': 'ARP', 'home': 'hou', 'away': 'utah'}, {'name': 'Mitchell, Donovan', 'name_ESPN': 'DonovanMitchell', 'odds': 1.89, 'line': 34.5, 'bet_on_stat': 'ARP', 'home': 'hou', 'away': 'utah'}, {'name': 'Porter Jr, Kevin', 'name_ESPN': 'KevinPorter Jr', 'odds': 1.89, 'line': 24.5, 'bet_on_stat': 'ARP', 'home': 'hou', 'away': 'utah'}, {'name': 'Hardaway Jr, Tim', 'name_ESPN': 'TimHardaway Jr', 'odds': 1.89, 'line': 23.5, 'bet_on_stat': 'ARP', 'home': 'dal', 'away': 'sa'}, {'name': 'Poeltl, J.', 'name_ESPN': 'J.Poeltl', 'odds': 1.89, 'line': 21.5, 'bet_on_stat': 'ARP', 'home': 'dal', 'away': 'sa'}, {'name': 'Finney-Smith, Dorian', 'name_ESPN': 'DorianFinney-Smith', 'odds': 1.89, 'line': 18.5, 'bet_on_stat': 'ARP', 'home': 'dal', 'away': 'sa'}, {'name': 'White, Derrick', 'name_ESPN': 'DerrickWhite', 'odds': 2.0, 'line': 25.5, 'bet_on_stat': 'ARP', 'home': 'dal', 'away': 'sa'}, {'name': 'Doncic, Luka', 'name_ESPN': 'LukaDoncic', 'odds': 1.89, 'line': 48.5, 'bet_on_stat': 'ARP', 'home': 'dal', 'away': 'sa'}, {'name': 'Johnson, Keldon', 'name_ESPN': 'KeldonJohnson', 'odds': 1.89, 'line': 22.5, 'bet_on_stat': 'ARP', 'home': 'dal', 'away': 'sa'}, {'name': 'Murray, Dejounte', 'name_ESPN': 'DejounteMurray', 'odds': 1.89, 'line': 32.5, 'bet_on_stat': 'ARP', 'home': 'dal', 'away': 'sa'}]

# %%
print(bets[3]) #todo: mapowanie
NORMALIZED_TEAM_NAME ={
  "Boston Celtics": "bos",
  "Brooklyn Nets": "bkn",
  "New York Knicks": "ny",
  "Philadelphia 76ers": "phi",
  "Toronto Raptors": "tor",
  "Chicago Bulls": "chi",
  "Cleveland Cavaliers": "cle",
  "Detroit Pistons": "det",
  "Indiana Pacers": "ind",
  "Milwaukee Bucks": "mil",
  "Denver Nuggets": "den",
  "Minnesota Timberwolves": "min",
  "Oklahoma City Thunders": "okc",
  "Portland Trail Blazers": "por",
  "Utah Jazz": "utah",
  "Golden State Warriors": "gs",
  "Los Angeles Clippers": "lac",
  "Los Angeles Lakers": "lal",
  "Phoenix Suns": "phx",
  "Sacramento Kings": "sac",
  "Atlanta Hawks": "atl",
  "Charlotte Hornets": "cha",
  "Miami Heat": "mia",
  "Orlando Magic": "orl",
  "Washington Wizards": "wsh",
  "Dallas Mavericks": "dal",
  "Houston Rockets": "hou",
  "Memphis Grizzlies": "mem",
  "New Orleans Pelicans": "no",
  "San Antonio Spurs": "sa"
}
# Out:
# {'name': 'Carter Jr., Wendell', 'name_ESPN': 'WendellCarter Jr.', 'odds': 1.9, 'line': 22.5, 'bet_on_stat': 'ARP', 'home': 'Orlando Magic', 'away': 'Charlotte Hornets', 'espn_home': 'orl'}

# %%
def bet_check(bet):
for bet in bets:
    get
    print(f"{bet['home']} : {bet['line']}")

# %%
bets
# Out:
# [{'name': 'Gobert, Rudy',
#   'name_ESPN': 'RudyGobert',
#   'odds': 1.89,
#   'line': 29.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Conley, Mike',
#   'name_ESPN': 'MikeConley',
#   'odds': 1.94,
#   'line': 23.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': "O'Neale, Royce",
#   'name_ESPN': "RoyceO'Neale",
#   'odds': 2.0,
#   'line': 15.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Theis, Daniel',
#   'name_ESPN': 'DanielTheis',
#   'odds': 1.89,
#   'line': 14.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Wood, Christian',
#   'name_ESPN': 'ChristianWood',
#   'odds': 1.89,
#   'line': 31.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Green, Jalen',
#   'name_ESPN': 'JalenGreen',
#   'odds': 1.89,
#   'line': 19.5,
# ...

# %%
def check_bet(bet):
    players = game_players(bet['home'], bet['away'])
    player_name_to_check = bet['name_ESPN']
    player_df = players[(players['player_name'] == player_name_to_check)]
    player_df['ARP'] = player_df['AST'] + player_df['REB'] + player_df['PTS']
    describe_df = player_df.describe(percentiles=[0.35, 0.5, 0.65])
    lower_bound = player_df['ARP'].quantile(0.30)
    upper_bound = player_df['ARP'].quantile(0.70)
    is_in_percentiles = lower_bound <= bet['line'] <= upper_bound

    print(f"{player_name_to_check:>16}    betline: {bet['line']:<5} is_in_percentiles:{is_in_percentiles} ({lower_bound:>4} - {upper_bound:>4})")

# %%
bets
# Out:
# [{'name': 'Gobert, Rudy',
#   'name_ESPN': 'RudyGobert',
#   'odds': 1.89,
#   'line': 29.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Conley, Mike',
#   'name_ESPN': 'MikeConley',
#   'odds': 1.94,
#   'line': 23.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': "O'Neale, Royce",
#   'name_ESPN': "RoyceO'Neale",
#   'odds': 2.0,
#   'line': 15.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Theis, Daniel',
#   'name_ESPN': 'DanielTheis',
#   'odds': 1.89,
#   'line': 14.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Wood, Christian',
#   'name_ESPN': 'ChristianWood',
#   'odds': 1.89,
#   'line': 31.5,
#   'bet_on_stat': 'ARP',
#   'home': 'Houston Rockets',
#   'away': 'Utah Jazz'},
#  {'name': 'Green, Jalen',
#   'name_ESPN': 'JalenGreen',
#   'odds': 1.89,
#   'line': 19.5,
# ...

# %%
for bet in bets:
    check_bet(bet)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19448/1494638911.py in <module>
#       1 for bet in bets:
# ----> 2     check_bet(bet)
#
# ~\AppData\Local\Temp/ipykernel_19448/594471336.py in check_bet(bet)
#       1 def check_bet(bet):
# ----> 2     players = game_players(bet['home'], bet['away'])
#       3     player_name_to_check = bet['name_ESPN']
#       4     player_df = players[(players['player_name'] == player_name_to_check)]
#       5     player_df['ARP'] = player_df['AST'] + player_df['REB'] + player_df['PTS']
#
# ~\PycharmProjects\nbawoj\bet_analizator.py in game_players(home, away)
#      19 # returns df with player gamelogs for home and away team
#      20 def game_players(home, away):
# ---> 21     home_df = pd.read_csv(f'team-{home}.csv')
#      22     home_df['gametype'] = 'home'
#      23     home_df['gameopp'] = away
#
# ...

# %%
teams_ids()
# Out:
# ['bos',
#  'bkn',
#  'ny',
#  'phi',
#  'tor',
#  'chi',
#  'cle',
#  'det',
#  'ind',
#  'mil',
#  'den',
#  'min',
#  'okc',
#  'por',
#  'utah',
#  'gs',
#  'lac',
#  'lal',
#  'phx',
#  'sac',
#  'atl',
#  'cha',
#  'mia',
#  'orl',
#  'wsh',
#  'dal',
#  'hou',
#  'mem',
#  'no',
#  'sa']
