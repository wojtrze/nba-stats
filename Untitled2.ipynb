# %%
#game analysis
import re
from random import randint
from time import sleep
from pandasgui import show

# import link as link
import requests
from bs4 import BeautifulSoup
import pandas as pd


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# returns df with player gamelogs for home and away team
def game_players(home, away):
    home_df = pd.read_csv(f'team-{home}.csv')
    home_df['gametype'] = 'home'
    home_df['gameopp'] = away
    away_df = pd.read_csv(f'team-{away}.csv')
    away_df['gametype'] = 'away'
    away_df['gameopp'] = home
    return pd.concat([home_df, away_df])

# selects only direct matchups (player against current opponent team)
def direct_matchups(plr_df):
    return plr_df[plr_df['gameopp'] == plr_df['OPP']]

def add_columns(plr_df):
    plr_df['ARP'] = plr_df['AST'] + plr_df['REB'] + plr_df['PTS']
    plr_df['PTS36'] = plr_df['PTS']/plr_df['MIN']*36
    plr_df['ARP36'] = plr_df['ARP']/plr_df['MIN']*36
    plr_df['lost_ponints'] = 2* ((plr_df['FGA']-plr_df['3PA']) - (plr_df['FGM']-plr_df['3PM'])) + (plr_df['FTA'] - plr_df['FTM']) + 3*(plr_df['3PA'] - plr_df['3PM'])
    plr_df['plusminus'] = plr_df['PTS'] - plr_df['lost_ponints']
    return plr_df

# dataframe z grami georga, gdzie nie grałKawhi vs gdzie grał
# without_player(players_df, player_to_check, 'KawhiLeonard').describe(percentiles=[0.35, 0.5, 0.65])
def without_player(df, player, player_b):
    when_player_b_didnt_play = pd.DataFrame()
    player_games = df[df['player_name'] == player]
    player_b_games = df[df['player_name'] == player_b]
    delete_when_play_together = pd.concat([player_games, player_b_games]).drop_duplicates(subset=['Date'], keep=False)
    when_player_b_didnt_play = delete_when_play_together[delete_when_play_together['player_name'] == player]
    return when_player_b_didnt_play

def describe_with_insights_t(df):
    #produces describe table allowing to make some choices on betting
    # dataframse can be produced to show diff direct player vs global player stats 
    df['games_count'] = df.count() # coś to nie działa 
    df_desc = df.describe(percentiles=[0.35, 0.5, 0.65])
    df_desc['deviation-to-mean'] = df_desc['std']/df_desc['mean']
    df_desc['between_percentiles_BP'] = df_desc['65%']-df_desc['35%']
    df_desc['percentiles_to_full_range_ratio'] = df_desc['between_percentiles_BP'] / df_desc['max']-df_desc['min']
    df_desc = df_desc.T
    return df_desc

nba = game_players(home ='sa', away = 'den')
player_to_check = "DejounteMurray"
nba = add_columns(nba)
nba['OPP'] = nba['OPP'].str.lower()
nba.drop(nba[nba['season_id'] == 2017].index, inplace=True)
direct = direct_matchups(nba)
direct.sample(7)
home = nba[nba['gametype'] == 'home']
home_direct = direct[direct['gametype'] == 'home']
away = nba[nba['gametype'] == 'away']
away_direct = direct[direct['gametype'] == 'away']
hhaa = nba[nba['gametype'] == nba['type']]

home_8_rotation = [4066218, 4065648, 4066211, 2990992, 3917376, 3032979, 4066354, 4397008]
away_8_rotation = [3934719, 4433134, 3423, 2991230, 2578240, 4277843, 4431679, 3948153]
hhaa[(hhaa['player_name'] == player_to_check)].describe()

h8 = direct[(direct['gametype'] == direct['type']) & (direct['gametype'] == 'home') & (direct.player_id.isin(home_8_rotation))] # home team 8 rotation for games played at home

a8 = direct[(direct['gametype'] == direct['type']) & (direct['gametype'] == 'away') & (direct.player_id.isin(away_8_rotation))] # away team 8 rotation for games played away

def player_desc_for_df(df, player_name):
    return df[df['player_name'] == player_name].describe(percentiles=[0.35, 0.5, 0.65])

direct[direct['player_name'] == player_to_check].describe(percentiles=[0.35, 0.5, 0.65])

players_df[(players_df['player_name'] == player_to_check) & (players_df['gametype'] == players_df['type'])].describe(percentiles=[0.35, 0.5, 0.65]) #only home or away
hhaa[(hhaa['player_name'] == player_to_check)]['ARP'].hist(density=True, histtype='step')
direct_matchups(hhaa[(hhaa['player_name'] == player_to_check)])['ARP'].hist(density=True, histtype='step')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20560/4217463490.py in <module>
#      80 direct[direct['player_name'] == player_to_check].describe(percentiles=[0.35, 0.5, 0.65])
#      81
# ---> 82 players_df[(players_df['player_name'] == player_to_check) & (players_df['gametype'] == players_df['type'])].describe(percentiles=[0.35, 0.5, 0.65]) #only home or away
#      83 hhaa[(hhaa['player_name'] == player_to_check)]['ARP'].hist(density=True, histtype='step')
#      84 direct_matchups(hhaa[(hhaa['player_name'] == player_to_check)])['ARP'].hist(density=True, histtype='step')
#
# NameError: name 'players_df' is not defined

# %%
direct_matchups(hhaa[(hhaa['player_name'] == player_to_check)]).describe()
# Out:
#        Unnamed: 0        MIN        FG%        3P%        FT%       REB  AST  \
# count     2.00000   2.000000   2.000000   2.000000   2.000000  2.000000  2.0
# mean      2.50000  29.000000  38.800000  16.650000  35.700000  4.000000  3.0
# std       2.12132   4.242641  19.516147  23.546656  50.487424  4.242641  0.0
# min       1.00000  26.000000  25.000000   0.000000   0.000000  1.000000  3.0
# 25%       1.75000  27.500000  31.900000   8.325000  17.850000  2.500000  3.0
# 50%       2.50000  29.000000  38.800000  16.650000  35.700000  4.000000  3.0
# 75%       3.25000  30.500000  45.700000  24.975000  53.550000  5.500000  3.0
# max       4.00000  32.000000  52.600000  33.300000  71.400000  7.000000  3.0
#
#        BLK       STL        PF        TO        PTS        FGM        FGA  \
# count  2.0  2.000000  2.000000  2.000000   2.000000   2.000000   2.000000
# mean   0.0  2.000000  3.000000  1.000000  15.000000   6.000000  13.500000
# std    0.0  1.414214  2.828427  1.414214  15.556349   5.656854   7.778175
# min    0.0  1.000000  1.000000  0.000000   4.000000   2.000000   8.000000
# 25%    0.0  1.500000  2.000000  0.500000   9.500000   4.000000  10.750000
# 50%    0.0  2.000000  3.000000  1.000000  15.000000   6.000000  13.500000
# 75%    0.0  2.500000  4.000000  1.500000  20.500000   8.000000  16.250000
# max    0.0  3.000000  5.000000  2.000000  26.000000  10.000000  19.000000
#
#             3PM       3PA       FTM       FTA    season_id  player_id  \
# count  2.000000  2.000000  2.000000  2.000000     2.000000        2.0
# mean   0.500000  2.500000  2.500000  3.500000  2019.500000  3907497.0
# std    0.707107  0.707107  3.535534  4.949747     0.707107        0.0
# min    0.000000  2.000000  0.000000  0.000000  2019.000000  3907497.0
# 25%    0.250000  2.250000  1.250000  1.750000  2019.250000  3907497.0
# 50%    0.500000  2.500000  2.500000  3.500000  2019.500000  3907497.0
# 75%    0.750000  2.750000  3.750000  5.250000  2019.750000  3907497.0
# max    1.000000  3.000000  5.000000  7.000000  2020.000000  3907497.0
#
#             ARP      PTS36      ARP36  lost_ponints  plusminus
# count   2.00000   2.000000   2.000000      2.000000   2.000000
# mean   22.00000  17.394231  25.788462     18.000000  -3.000000
# std    19.79899  16.766590  20.805257      5.656854   9.899495
# min     8.00000   5.538462  11.076923     14.000000 -10.000000
# 25%    15.00000  11.466346  18.432692     16.000000  -6.500000
# 50%    22.00000  17.394231  25.788462     18.000000  -3.000000
# 75%    29.00000  23.322115  33.144231     20.000000   0.500000
# max    36.00000  29.250000  40.500000     22.000000   4.000000

# %%
# Out:
# <AxesSubplot:>

# %%
player_desc_for_df(direct, player_name)

# %%
# number_of_games_for_player(player_name)
nba[nba['player_name'] == player_to_check].count()[1]
# Out:
# 225

# %%
direct[(direct['gametype'] == direct['type']) & (direct['gametype'] == 'home')].describe() #home team stats when playing home

# %%
h8 = direct[(direct['gametype'] == direct['type']) & (direct['gametype'] == 'home') & (direct.player_id.isin(home_8_rotation))] # home team 8 rotation for games played at home

a8 = direct[(direct['gametype'] == direct['type']) & (direct['gametype'] == 'away') & (direct.player_id.isin(away_8_rotation))] # away team 8 rotation for games played away

# %%
direct.describe()
# Out:
#        Unnamed: 0         MIN         FG%         3P%         FT%         REB  \
# count  192.000000  192.000000  192.000000  192.000000  192.000000  192.000000
# mean     5.203125   26.661458   44.107292   29.038542   48.293229    5.036458
# std      3.881139   11.488441   23.652782   27.936448   43.460067    3.423620
# min      0.000000    2.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000   18.000000   31.300000    0.000000    0.000000    2.000000
# 50%      4.000000   28.000000   41.700000   25.000000   50.000000    5.000000
# 75%      8.000000   36.000000   55.600000   50.000000  100.000000    7.000000
# max     14.000000   54.000000  100.000000  100.000000  100.000000   16.000000
#
#               AST         BLK         STL          PF          TO         PTS  \
# count  192.000000  192.000000  192.000000  192.000000  192.000000  192.000000
# mean     2.510417    0.515625    0.885417    2.223958    1.640625   12.291667
# std      2.508602    0.868148    1.100878    1.600670    1.472618    8.602832
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    1.000000    1.000000    5.000000
# 50%      2.000000    0.000000    1.000000    2.000000    1.000000   11.000000
# 75%      4.000000    1.000000    1.000000    3.000000    3.000000   18.000000
# max     11.000000    5.000000    6.000000    6.000000    6.000000   40.000000
#
#               FGM         FGA         3PM         3PA         FTM         FTA  \
# count  192.000000  192.000000  192.000000  192.000000  192.000000  192.000000
# mean     4.427083    9.942708    1.479167    3.916667    1.958333    2.500000
# std      3.068996    6.282349    1.595013    3.215365    2.444854    2.887054
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    5.000000    0.000000    1.000000    0.000000    0.000000
# 50%      4.000000    9.000000    1.000000    4.000000    1.000000    2.000000
# 75%      6.000000   15.000000    2.000000    6.000000    3.000000    4.000000
# max     13.000000   30.000000    7.000000   13.000000   14.000000   16.000000
#
#          season_id     player_id         ARP       PTS36       ARP36  \
# count   192.000000  1.920000e+02  192.000000  192.000000  192.000000
# mean   2019.036458  3.183893e+06   19.838542   15.470785   25.654429
# std       0.642088  1.286642e+06   11.779385    8.509354   10.744379
# min    2018.000000  3.213000e+03    0.000000    0.000000    0.000000
# 25%    2019.000000  2.991230e+06   11.000000    9.669231   18.708578
# 50%    2019.000000  3.917376e+06   19.000000   15.215311   26.058824
# 75%    2019.000000  4.065648e+06   28.250000   20.826923   32.133713
# max    2020.000000  4.431679e+06   52.000000   45.000000   60.000000
#
#        lost_ponints   plusminus  games_count
# count    192.000000  192.000000          0.0
# mean      14.010417   -1.718750          NaN
# std       10.017780    8.409921          NaN
# min        0.000000  -25.000000          NaN
# 25%        6.000000   -6.250000          NaN
# 50%       13.000000   -1.000000          NaN
# 75%       20.250000    4.000000          NaN
# max       47.000000   21.000000          NaN

# %%
def player_desc_for_df(df, player_name):
    return df[df['player_name'] == player_name].describe(percentiles=[0.35, 0.5, 0.65])

direct[direct['player_name'] == player_to_check].describe(percentiles=[0.35, 0.5, 0.65])

players_df[(players_df['player_name'] == player_to_check) & (players_df['gametype'] == players_df['type'])].describe(percentiles=[0.35, 0.5, 0.65]) #only home or away

# %%
describe_with_insights_t(nba)

# %%
direct.sample(2)
# Out:
#       Unnamed: 0  OPP    Result   MIN   FG%    3P%    FT%  REB  AST  BLK  STL  \
# 126            6  sac  W123-101  31.0  66.7   66.7  100.0  2.0  1.0  0.0  1.0
# 2731           0  sac  W113-105  16.0  50.0  100.0    0.0  2.0  2.0  0.0  1.0
#
#        PF   TO   PTS   FGM   FGA  3PM  3PA  FTM  FTA  type        Date  \
# 126   2.0  1.0  30.0  10.0  15.0  6.0  9.0  4.0  4.0  home  2020-01-18
# 2731  1.0  0.0   5.0   2.0   4.0  1.0  1.0  0.0  0.0  away  2020-12-17
#
#       season_id  player_id      player_name  team gametype gameopp   ARP  \
# 126        2019       3593  BojanBogdanovic  utah     home     sac  33.0
# 2731       2020    3133817     EricPaschall  utah     home     sac   9.0
#
#          PTS36      ARP36  lost_ponints  plusminus
# 126   34.83871  38.322581          13.0       17.0
# 2731  11.25000  20.250000           4.0        1.0

# %% [raw]
# bets

# %%
hhaa.groupby('player_name').median()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_20560/2541960244.py in <module>
# ----> 1 hhaa.groupby('player_name').median()
#
# NameError: name 'hhaa' is not defined
